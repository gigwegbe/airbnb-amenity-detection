# %% [markdown]
# # Open Images data preparation
#
# The goal of this notebook is to get the public Open Images data formatted in such a way it can be used with DETR.
#
# To download the Open Images, we're using the following script:
# - https://github.com/spmallick/learnopencv/blob/master/downloadOpenImages/downloadOI.py

# %%
import sys
import numpy as np

# %%
# Download required meta-files
# !wget https://storage.googleapis.com/openimages/2018_04/class-descriptions-boxable.csv
 
# !wget https://storage.googleapis.com/openimages/2018_04/train/train-annotations-bbox.csv
 
# !wget https://storage.googleapis.com/openimages/2018_04/validation/validation-annotations-bbox.csv
 
# !wget https://storage.googleapis.com/openimages/2018_04/test/test-annotations-bbox.csv
# Out:
# --2020-08-15 02:23:36--  https://storage.googleapis.com/openimages/2018_04/class-descriptions-boxable.csv
# Resolving storage.googleapis.com... 172.217.14.208, 172.217.14.240, 216.58.193.80, ...
# Connecting to storage.googleapis.com|172.217.14.208|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11255 (11K) [text/csv]
# Saving to: ‘class-descriptions-boxable.csv’
#
# class-descriptions- 100%[===================>]  10.99K  --.-KB/s    in 0s
#
# 2020-08-15 02:23:36 (24.2 MB/s) - ‘class-descriptions-boxable.csv’ saved [11255/11255]
#
# --2020-08-15 02:23:36--  https://storage.googleapis.com/openimages/2018_04/train/train-annotations-bbox.csv
# Resolving storage.googleapis.com... 216.58.217.48, 216.58.193.80, 172.217.14.240, ...
# Connecting to storage.googleapis.com|216.58.217.48|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1194033454 (1.1G) [text/csv]
# Saving to: ‘train-annotations-bbox.csv’
#
# train-annotations-b 100%[===================>]   1.11G  94.4MB/s    in 18s
#
# 2020-08-15 02:23:54 (63.0 MB/s) - ‘train-annotations-bbox.csv’ saved [1194033454/1194033454]
#
# --2020-08-15 02:23:54--  https://storage.googleapis.com/openimages/2018_04/validation/validation-annotations-bbox.csv
# Resolving storage.googleapis.com... 216.58.217.48, 216.58.193.80, 172.217.14.240, ...
# Connecting to storage.googleapis.com|216.58.217.48|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 17074036 (16M) [text/csv]
# Saving to: ‘validation-annotations-bbox.csv’
#
# validation-annotati 100%[===================>]  16.28M  17.2MB/s    in 0.9s
#
# 2020-08-15 02:23:56 (17.2 MB/s) - ‘validation-annotations-bbox.csv’ saved [17074036/17074036]
#
# --2020-08-15 02:23:56--  https://storage.googleapis.com/openimages/2018_04/test/test-annotations-bbox.csv
# Resolving storage.googleapis.com... 216.58.217.48, 216.58.193.80, 172.217.14.240, ...
# Connecting to storage.googleapis.com|216.58.217.48|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 52174204 (50M) [text/csv]
# Saving to: ‘test-annotations-bbox.csv’
#
# test-annotations-bb 100%[===================>]  49.76M  13.0MB/s    in 4.3s
#
# 2020-08-15 02:24:00 (11.6 MB/s) - ‘test-annotations-bbox.csv’ saved [52174204/52174204]

# %% [markdown]
# ### Testing with a small sample of Google Open Images.

# %%
# !python3 downloadOI.py --mode train --classes 'Ice_cream,Cookie' 

#Download bathtub and toilet images
# !python3 downloadOI.py --classes 'Bathtub,Toilet' --mode validation
# Out:
# Class 0 : Ice_cream
# Class 1 : Cookie
# Annotation Count : 6992
# Number of images to be downloaded : 2452
# 100%|███████████████████████████████████████| 2452/2452 [10:00<00:00,  4.08it/s]
# Class 0 : Bathtub
# Class 1 : Toilet
# Annotation Count : 43
# Number of images to be downloaded : 39
# 100%|███████████████████████████████████████████| 39/39 [00:11<00:00,  3.36it/s]

# %%
# Classes of amenities Airbnb mostly cares about
subset = ["Toilet",
          "Swimming_pool",
          "Bed",
          "Biliard_table",
          "Sink",
          "Fountain",
          "Oven",
          "Ceiling_fan",
          "Television",
          "Microwave_oven",
          "Gas_stove",
          "Refrigerator",
          "Kitchen_&_dining_room_table",
          "Washing_machine",
          "Bathtub",
          "Stairs",
          "Fireplace",
          "Pillow",
          "Mirror",
          "Shower",
          "Couch",
          "Countertop",
          "Coffeemaker",
          "Dishwasher",
          "Sofa_bed",
          "Tree_house",
          "Towel",
          "Porch",
          "Wine_rack",
          "Jacuzzi"]

# %% [markdown]
# # Converting Images/labels to COCO

# %% [markdown]
#  Convert Google Open image Images/labels to with annotations from http://cocodataset.org. We expect the directory structure to be the following:
#  ```
#  path/to/coco/
#   annotations/  # annotation json files
#   train2017/    # train images
#   val2017/      # val images
#  ```

# %% [markdown]
# The expected COCO dataset format:

# %% [markdown]
# ```
# annotation{
#     "id": int,
#     "image_id": int,
#     "category_id": int,
#     "segmentation": RLE or [polygon],
#     "area": float,
#     "bbox": [x,y,width,height],
#     "iscrowd": 0 or 1,
# }
#
# categories[{
#     "id": int,
#     "name": str,
#     "supercategory": str,
# }]
# ```

# %% [markdown]
# Current style:
# - Filepath: `validation/Toilet/0d0719cfd8e417b7.jpg`
# - Label filename: `0d0719cfd8e417b7.txt`
# - Image filename: `0d0719cfd8e417b7.jpg`
# - Contents of label file: `Toilet,0.093371,0.986232,0.189984,0.965806`
#
# I'll need a way to:
# 1. Traverse different file paths
# 2. Gather filenames and explore their text contents
# 3. Seek duplicates and make sure they contain multiple labels
#
# What I should end up with is:
# - A single file of images (can convert this to train/test later)
# - A dictionary of all of the different parameters for each image path
#     - Perhaps I could do this with a Pandas dataframe? So it's visual? Then convert it to JSON maybe?

# %%
import pandas as pd
df = pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import os
file_ids = [os.path.splitext(file)[0] for file in os.listdir("validation/Bathtub")]
len(file_ids), len(set(file_ids))
# Out:
# (28, 14)

# %%
fi_id = [os.path.splitext(file)[0] for file in os.listdir('validation/Bathtub')]

# %%
unique_ids = list(set(file_ids))
#unique_ids

# %%
unique_ids
# Out:
# ['2f2039140c8b1f2b',
#  'cd727c5e0d2cfc1b',
#  '11dcac4ca5923a58',
#  '789cc0283c0e18af',
#  '2f0a18a409d5a769',
#  '8e562fee6ff208f7',
#  '837b3d11ff02f116',
#  '784bba5f12ee7c35',
#  '3f66fdf9688514d4',
#  '15348e4f2c7ebe0f',
#  'eccb080e57b2aac5',
#  '822f20d881eebeb9',
#  'd7d469cb4c7e8cd2',
#  'ddd3f96ff7f0bc78']

# %%
df["image_id"] = unique_ids

# %%
df.head(5)
# Out:
#            image_id
# 0  2f2039140c8b1f2b
# 1  cd727c5e0d2cfc1b
# 2  11dcac4ca5923a58
# 3  789cc0283c0e18af
# 4  2f0a18a409d5a769

# %%
# %%time
img_files = []
label_files = []
for path, dirnames, filenames in os.walk("validation"):
    for file in filenames:
        if ".jpg" in file:
            #print(os.path.join(path, file))
            img_files.append(os.path.join(path, file))
        else:
            label_files.append(os.path.join(path, file))
            #print(os.path.join(path, file))
        #img_files = set(img_files.append(os.path.join(path, file)))
img_files, label_files
# Out:
# CPU times: user 0 ns, sys: 2.5 ms, total: 2.5 ms
# Wall time: 1.37 ms
# (['validation/Bathtub/3f66fdf9688514d4.jpg',
#   'validation/Bathtub/2f2039140c8b1f2b.jpg',
#   'validation/Bathtub/cd727c5e0d2cfc1b.jpg',
#   'validation/Bathtub/15348e4f2c7ebe0f.jpg',
#   'validation/Bathtub/789cc0283c0e18af.jpg',
#   'validation/Bathtub/784bba5f12ee7c35.jpg',
#   'validation/Bathtub/eccb080e57b2aac5.jpg',
#   'validation/Bathtub/2f0a18a409d5a769.jpg',
#   'validation/Bathtub/8e562fee6ff208f7.jpg',
#   'validation/Bathtub/822f20d881eebeb9.jpg',
#   'validation/Bathtub/d7d469cb4c7e8cd2.jpg',
#   'validation/Bathtub/11dcac4ca5923a58.jpg',
#   'validation/Bathtub/ddd3f96ff7f0bc78.jpg',
#   'validation/Bathtub/837b3d11ff02f116.jpg',
#   'validation/Toilet/b2dc8e2437e8803f.jpg',
#   'validation/Toilet/36d8c654fba5f337.jpg',
#   'validation/Toilet/217b95a71cb220f8.jpg',
#   'validation/Toilet/3a511ef0f68cc438.jpg',
#   'validation/Toilet/42298c9659ce6603.jpg',
#   'validation/Toilet/17f698ec871569ca.jpg',
#   'validation/Toilet/c7312a8b436f5e90.jpg',
#   'validation/Toilet/b3a65783709539de.jpg',
#   'validation/Toilet/47ab0e73c33bdefd.jpg',
#   'validation/Toilet/0d0719cfd8e417b7.jpg',
#   'validation/Toilet/d60e1c25e87d8b45.jpg',
#   'validation/Toilet/f90eac5444f62b19.jpg',
#   'validation/Toilet/2ff2bb609a057f7a.jpg',
#   'validation/Toilet/be84a3da54658167.jpg',
#   'validation/Toilet/2f0a18a409d5a769.jpg',
#   'validation/Toilet/c1eefc708000b69f.jpg',
#   'validation/Toilet/7c2825a3d8e0ed29.jpg',
#   'validation/Toilet/40a69f79da2aeaaa.jpg',
#   'validation/Toilet/85ccc93d1f941931.jpg',
#   'validation/Toilet/eaa75967cbc70ac1.jpg',
#   'validation/Toilet/3454c87a14067798.jpg',
#   'validation/Toilet/e108d68162990dfb.jpg',
#   'validation/Toilet/e6e05b56799fefba.jpg',
#   'validation/Toilet/539e0871494dea5d.jpg',
#   'validation/Toilet/b821cc12eede040e.jpg'],
#  ['validation/Bathtub/784bba5f12ee7c35.txt',
#   'validation/Bathtub/789cc0283c0e18af.txt',
#   'validation/Bathtub/2f2039140c8b1f2b.txt',
#   'validation/Bathtub/cd727c5e0d2cfc1b.txt',
#   'validation/Bathtub/822f20d881eebeb9.txt',
#   'validation/Bathtub/8e562fee6ff208f7.txt',
#   'validation/Bathtub/eccb080e57b2aac5.txt',
#   'validation/Bathtub/ddd3f96ff7f0bc78.txt',
#   'validation/Bathtub/3f66fdf9688514d4.txt',
#   'validation/Bathtub/d7d469cb4c7e8cd2.txt',
#   'validation/Bathtub/11dcac4ca5923a58.txt',
#   'validation/Bathtub/15348e4f2c7ebe0f.txt',
#   'validation/Bathtub/837b3d11ff02f116.txt',
#   'validation/Bathtub/2f0a18a409d5a769.txt',
#   'validation/Toilet/3a511ef0f68cc438.txt',
#   'validation/Toilet/47ab0e73c33bdefd.txt',
#   'validation/Toilet/f90eac5444f62b19.txt',
#   'validation/Toilet/85ccc93d1f941931.txt',
#   'validation/Toilet/42298c9659ce6603.txt',
#   'validation/Toilet/40a69f79da2aeaaa.txt',
#   'validation/Toilet/b3a65783709539de.txt',
#   'validation/Toilet/217b95a71cb220f8.txt',
#   'validation/Toilet/0d0719cfd8e417b7.txt',
#   'validation/Toilet/e108d68162990dfb.txt',
#   'validation/Toilet/2ff2bb609a057f7a.txt',
#   'validation/Toilet/eaa75967cbc70ac1.txt',
#   'validation/Toilet/e6e05b56799fefba.txt',
#   'validation/Toilet/be84a3da54658167.txt',
#   'validation/Toilet/c1eefc708000b69f.txt',
#   'validation/Toilet/c7312a8b436f5e90.txt',
#   'validation/Toilet/b821cc12eede040e.txt',
#   'validation/Toilet/d60e1c25e87d8b45.txt',
#   'validation/Toilet/7c2825a3d8e0ed29.txt',
#   'validation/Toilet/b2dc8e2437e8803f.txt',
#   'validation/Toilet/3454c87a14067798.txt',
#   'validation/Toilet/36d8c654fba5f337.txt',
#   'validation/Toilet/17f698ec871569ca.txt',
#   'validation/Toilet/2f0a18a409d5a769.txt',
#   'validation/Toilet/539e0871494dea5d.txt'])

# %%
len(img_files)
# Out:
# 39

# %%
len(label_files)
# Out:
# 39

# %%
os.path.splitext(img_files[0])[0].split("/")
# Out:
# ['validation', 'Bathtub', '3f66fdf9688514d4']

# %%
# %%time
img_details = []
for img_path in img_files:
    dataset, label, img_id = os.path.splitext(img_path)[0].split("/")
    img_detail = {
        "dataset": dataset,
        "label": label,
        "id": img_id,
        "file_name": img_path
    }
    img_details.append(img_detail)
img_details
# Out:
# CPU times: user 127 µs, sys: 0 ns, total: 127 µs
# Wall time: 132 µs
# [{'dataset': 'validation',
#   'label': 'Bathtub',
#   'id': '3f66fdf9688514d4',
#   'file_name': 'validation/Bathtub/3f66fdf9688514d4.jpg'},
#  {'dataset': 'validation',
#   'label': 'Bathtub',
#   'id': '2f2039140c8b1f2b',
#   'file_name': 'validation/Bathtub/2f2039140c8b1f2b.jpg'},
#  {'dataset': 'validation',
#   'label': 'Bathtub',
#   'id': 'cd727c5e0d2cfc1b',
#   'file_name': 'validation/Bathtub/cd727c5e0d2cfc1b.jpg'},
#  {'dataset': 'validation',
#   'label': 'Bathtub',
#   'id': '15348e4f2c7ebe0f',
#   'file_name': 'validation/Bathtub/15348e4f2c7ebe0f.jpg'},
#  {'dataset': 'validation',
#   'label': 'Bathtub',
#   'id': '789cc0283c0e18af',
#   'file_name': 'validation/Bathtub/789cc0283c0e18af.jpg'},
#  {'dataset': 'validation',
#   'label': 'Bathtub',
#   'id': '784bba5f12ee7c35',
#   'file_name': 'validation/Bathtub/784bba5f12ee7c35.jpg'},
#  {'dataset': 'validation',
#   'label': 'Bathtub',
#   'id': 'eccb080e57b2aac5',
#   'file_name': 'validation/Bathtub/eccb080e57b2aac5.jpg'},
#  {'dataset': 'validation',
#   'label': 'Bathtub',
#   'id': '2f0a18a409d5a769',
#   'file_name': 'validation/Bathtub/2f0a18a409d5a769.jpg'},
#  {'dataset': 'validation',
#   'label': 'Bathtub',
#   'id': '8e562fee6ff208f7',
#   'file_name': 'validation/Bathtub/8e562fee6ff208f7.jpg'},
#  {'dataset': 'validation',
#   'label': 'Bathtub',
#   'id': '822f20d881eebeb9',
#   'file_name': 'validation/Bathtub/822f20d881eebeb9.jpg'},
#  {'dataset': 'validation',
#   'label': 'Bathtub',
#   'id': 'd7d469cb4c7e8cd2',
#   'file_name': 'validation/Bathtub/d7d469cb4c7e8cd2.jpg'},
#  {'dataset': 'validation',
#   'label': 'Bathtub',
#   'id': '11dcac4ca5923a58',
#   'file_name': 'validation/Bathtub/11dcac4ca5923a58.jpg'},
#  {'dataset': 'validation',
#   'label': 'Bathtub',
#   'id': 'ddd3f96ff7f0bc78',
#   'file_name': 'validation/Bathtub/ddd3f96ff7f0bc78.jpg'},
#  {'dataset': 'validation',
#   'label': 'Bathtub',
#   'id': '837b3d11ff02f116',
#   'file_name': 'validation/Bathtub/837b3d11ff02f116.jpg'},
#  {'dataset': 'validation',
#   'label': 'Toilet',
#   'id': 'b2dc8e2437e8803f',
#   'file_name': 'validation/Toilet/b2dc8e2437e8803f.jpg'},
#  {'dataset': 'validation',
#   'label': 'Toilet',
#   'id': '36d8c654fba5f337',
#   'file_name': 'validation/Toilet/36d8c654fba5f337.jpg'},
#  {'dataset': 'validation',
#   'label': 'Toilet',
#   'id': '217b95a71cb220f8',
#   'file_name': 'validation/Toilet/217b95a71cb220f8.jpg'},
#  {'dataset': 'validation',
#   'label': 'Toilet',
#   'id': '3a511ef0f68cc438',
#   'file_name': 'validation/Toilet/3a511ef0f68cc438.jpg'},
#  {'dataset': 'validation',
#   'label': 'Toilet',
#   'id': '42298c9659ce6603',
#   'file_name': 'validation/Toilet/42298c9659ce6603.jpg'},
#  {'dataset': 'validation',
#   'label': 'Toilet',
#   'id': '17f698ec871569ca',
#   'file_name': 'validation/Toilet/17f698ec871569ca.jpg'},
#  {'dataset': 'validation',
#   'label': 'Toilet',
#   'id': 'c7312a8b436f5e90',
#   'file_name': 'validation/Toilet/c7312a8b436f5e90.jpg'},
#  {'dataset': 'validation',
#   'label': 'Toilet',
#   'id': 'b3a65783709539de',
#   'file_name': 'validation/Toilet/b3a65783709539de.jpg'},
#  {'dataset': 'validation',
#   'label': 'Toilet',
#   'id': '47ab0e73c33bdefd',
#   'file_name': 'validation/Toilet/47ab0e73c33bdefd.jpg'},
#  {'dataset': 'validation',
#   'label': 'Toilet',
#   'id': '0d0719cfd8e417b7',
#   'file_name': 'validation/Toilet/0d0719cfd8e417b7.jpg'},
#  {'dataset': 'validation',
#   'label': 'Toilet',
#   'id': 'd60e1c25e87d8b45',
#   'file_name': 'validation/Toilet/d60e1c25e87d8b45.jpg'},
#  {'dataset': 'validation',
#   'label': 'Toilet',
#   'id': 'f90eac5444f62b19',
#   'file_name': 'validation/Toilet/f90eac5444f62b19.jpg'},
#  {'dataset': 'validation',
#   'label': 'Toilet',
#   'id': '2ff2bb609a057f7a',
#   'file_name': 'validation/Toilet/2ff2bb609a057f7a.jpg'},
#  {'dataset': 'validation',
#   'label': 'Toilet',
#   'id': 'be84a3da54658167',
#   'file_name': 'validation/Toilet/be84a3da54658167.jpg'},
#  {'dataset': 'validation',
#   'label': 'Toilet',
#   'id': '2f0a18a409d5a769',
#   'file_name': 'validation/Toilet/2f0a18a409d5a769.jpg'},
#  {'dataset': 'validation',
#   'label': 'Toilet',
#   'id': 'c1eefc708000b69f',
#   'file_name': 'validation/Toilet/c1eefc708000b69f.jpg'},
#  {'dataset': 'validation',
#   'label': 'Toilet',
#   'id': '7c2825a3d8e0ed29',
#   'file_name': 'validation/Toilet/7c2825a3d8e0ed29.jpg'},
#  {'dataset': 'validation',
#   'label': 'Toilet',
#   'id': '40a69f79da2aeaaa',
#   'file_name': 'validation/Toilet/40a69f79da2aeaaa.jpg'},
#  {'dataset': 'validation',
#   'label': 'Toilet',
#   'id': '85ccc93d1f941931',
#   'file_name': 'validation/Toilet/85ccc93d1f941931.jpg'},
#  {'dataset': 'validation',
#   'label': 'Toilet',
#   'id': 'eaa75967cbc70ac1',
#   'file_name': 'validation/Toilet/eaa75967cbc70ac1.jpg'},
#  {'dataset': 'validation',
#   'label': 'Toilet',
#   'id': '3454c87a14067798',
#   'file_name': 'validation/Toilet/3454c87a14067798.jpg'},
#  {'dataset': 'validation',
#   'label': 'Toilet',
#   'id': 'e108d68162990dfb',
#   'file_name': 'validation/Toilet/e108d68162990dfb.jpg'},
#  {'dataset': 'validation',
#   'label': 'Toilet',
#   'id': 'e6e05b56799fefba',
#   'file_name': 'validation/Toilet/e6e05b56799fefba.jpg'},
#  {'dataset': 'validation',
#   'label': 'Toilet',
#   'id': '539e0871494dea5d',
#   'file_name': 'validation/Toilet/539e0871494dea5d.jpg'},
#  {'dataset': 'validation',
#   'label': 'Toilet',
#   'id': 'b821cc12eede040e',
#   'file_name': 'validation/Toilet/b821cc12eede040e.jpg'}]

# %%
# Now let's get bounding box information
label_details = []
for label_path in label_files:
    dataset, label, img_id = os.path.splitext(label_path)[0].split("/")
    with open(label_path, "r") as file:
        data = file.read().replace("\n", "").split(",")
        XMin, XMax, YMin, YMax = data[1], data[2], data[3], data[4]
        # bbox dimensions = XMin, XMax, YMin, YMax
        #bbox = [float(i) for i in [data[1], data[2], data[3], data[4]]]
        
    label_detail = {
        "dataset": dataset,
        "label": label,
        "id": img_id,
        "bbox": [XMin, XMax, YMin, YMax]
    }
    label_details.append(label_detail)
label_details
# Out:
# [{'dataset': 'validation',
#   'label': 'Bathtub',
#   'id': '784bba5f12ee7c35',
#   'bbox': ['0.000000', '1.000000', '0.000000', '1.000000']},
#  {'dataset': 'validation',
#   'label': 'Bathtub',
#   'id': '789cc0283c0e18af',
#   'bbox': ['0.039686', '0.948718', '0.119581', '1.000000']},
#  {'dataset': 'validation',
#   'label': 'Bathtub',
#   'id': '2f2039140c8b1f2b',
#   'bbox': ['0.000000', '1.000000', '0.000000', '1.000000']},
#  {'dataset': 'validation',
#   'label': 'Bathtub',
#   'id': 'cd727c5e0d2cfc1b',
#   'bbox': ['0.048442', '0.980496', '0.427911', '0.806723']},
#  {'dataset': 'validation',
#   'label': 'Bathtub',
#   'id': '822f20d881eebeb9',
#   'bbox': ['0.000000', '1.000000', '0.181437', '0.963113']},
#  {'dataset': 'validation',
#   'label': 'Bathtub',
#   'id': '8e562fee6ff208f7',
#   'bbox': ['0.013755', '0.513952', '0.476118', '0.999980Bathtub']},
#  {'dataset': 'validation',
#   'label': 'Bathtub',
#   'id': 'eccb080e57b2aac5',
#   'bbox': ['0.303341', '0.905829', '0.470852', '0.999948']},
#  {'dataset': 'validation',
#   'label': 'Bathtub',
#   'id': 'ddd3f96ff7f0bc78',
#   'bbox': ['0.251883', '0.976808', '0.460918', '1.000000']},
#  {'dataset': 'validation',
#   'label': 'Bathtub',
#   'id': '3f66fdf9688514d4',
#   'bbox': ['0.050368', '0.933495', '0.250992', '1.000000']},
#  {'dataset': 'validation',
#   'label': 'Bathtub',
#   'id': 'd7d469cb4c7e8cd2',
#   'bbox': ['0.000081', '0.999159', '0.435396', '1.000000']},
#  {'dataset': 'validation',
#   'label': 'Bathtub',
#   'id': '11dcac4ca5923a58',
#   'bbox': ['0.360645', '0.999988', '0.000000', '1.000000']},
#  {'dataset': 'validation',
#   'label': 'Bathtub',
#   'id': '15348e4f2c7ebe0f',
#   'bbox': ['0.087330', '0.999973', '0.600616', '0.999962']},
#  {'dataset': 'validation',
#   'label': 'Bathtub',
#   'id': '837b3d11ff02f116',
#   'bbox': ['0.000000', '0.669035', '0.372941', '1.000000']},
#  {'dataset': 'validation',
#   'label': 'Bathtub',
#   'id': '2f0a18a409d5a769',
#   'bbox': ['0.157351', '1.000000', '0.328732', '0.927573']},
#  {'dataset': 'validation',
#   'label': 'Toilet',
#   'id': '3a511ef0f68cc438',
#   'bbox': ['0.124107', '0.338616', '0.755953', '0.978802']},
#  {'dataset': 'validation',
#   'label': 'Toilet',
#   'id': '47ab0e73c33bdefd',
#   'bbox': ['0.197381', '0.922556', '0.468605', '0.829202']},
#  {'dataset': 'validation',
#   'label': 'Toilet',
#   'id': 'f90eac5444f62b19',
#   'bbox': ['0.405385', '0.896555', '0.624074', '1.000000']},
#  {'dataset': 'validation',
#   'label': 'Toilet',
#   'id': '85ccc93d1f941931',
#   'bbox': ['0.369258', '0.746107', '0.152027', '1.000000']},
#  {'dataset': 'validation',
#   'label': 'Toilet',
#   'id': '42298c9659ce6603',
#   'bbox': ['0.301737', '0.792065', '0.190453', '0.838540']},
#  {'dataset': 'validation',
#   'label': 'Toilet',
#   'id': '40a69f79da2aeaaa',
#   'bbox': ['0.014170', '0.473459', '0.348211', '0.999983']},
#  {'dataset': 'validation',
#   'label': 'Toilet',
#   'id': 'b3a65783709539de',
#   'bbox': ['0.184904', '0.846895', '0.060172', '0.961222']},
#  {'dataset': 'validation',
#   'label': 'Toilet',
#   'id': '217b95a71cb220f8',
#   'bbox': ['0.438669', '0.602654', '0.449081', '0.532643']},
#  {'dataset': 'validation',
#   'label': 'Toilet',
#   'id': '0d0719cfd8e417b7',
#   'bbox': ['0.093371', '0.986232', '0.189984', '0.965806']},
#  {'dataset': 'validation',
#   'label': 'Toilet',
#   'id': 'e108d68162990dfb',
#   'bbox': ['0.360770', '0.656517', '0.410382', '0.886037']},
#  {'dataset': 'validation',
#   'label': 'Toilet',
#   'id': '2ff2bb609a057f7a',
#   'bbox': ['0.182173', '0.798462', '0.273742', '0.942715']},
#  {'dataset': 'validation',
#   'label': 'Toilet',
#   'id': 'eaa75967cbc70ac1',
#   'bbox': ['0.095922', '0.870645', '0.124023', '0.570180']},
#  {'dataset': 'validation',
#   'label': 'Toilet',
#   'id': 'e6e05b56799fefba',
#   'bbox': ['0.059556', '0.956108', '0.000000', '0.507183']},
#  {'dataset': 'validation',
#   'label': 'Toilet',
#   'id': 'be84a3da54658167',
#   'bbox': ['0.246185', '0.776473', '0.728370', '1.000000']},
#  {'dataset': 'validation',
#   'label': 'Toilet',
#   'id': 'c1eefc708000b69f',
#   'bbox': ['0.201985', '0.772443', '0.097975', '0.983168']},
#  {'dataset': 'validation',
#   'label': 'Toilet',
#   'id': 'c7312a8b436f5e90',
#   'bbox': ['0.483064', '0.583230', '0.148464', '0.254009Toilet']},
#  {'dataset': 'validation',
#   'label': 'Toilet',
#   'id': 'b821cc12eede040e',
#   'bbox': ['0.520803', '0.940757', '0.603367', '0.988894']},
#  {'dataset': 'validation',
#   'label': 'Toilet',
#   'id': 'd60e1c25e87d8b45',
#   'bbox': ['0.405653', '1.000000', '0.146613', '0.626838']},
#  {'dataset': 'validation',
#   'label': 'Toilet',
#   'id': '7c2825a3d8e0ed29',
#   'bbox': ['0.207057', '0.415161', '0.809775', '0.999841']},
#  {'dataset': 'validation',
#   'label': 'Toilet',
#   'id': 'b2dc8e2437e8803f',
#   'bbox': ['0.337954', '0.695044', '0.258797', '0.857483']},
#  {'dataset': 'validation',
#   'label': 'Toilet',
#   'id': '3454c87a14067798',
#   'bbox': ['0.077027', '0.306008', '0.811938', '1.000000Toilet']},
#  {'dataset': 'validation',
#   'label': 'Toilet',
#   'id': '36d8c654fba5f337',
#   'bbox': ['0.063034', '0.805088', '0.000000', '0.697051']},
#  {'dataset': 'validation',
#   'label': 'Toilet',
#   'id': '17f698ec871569ca',
#   'bbox': ['0.160562', '0.475538', '0.181890', '0.847251Toilet']},
#  {'dataset': 'validation',
#   'label': 'Toilet',
#   'id': '2f0a18a409d5a769',
#   'bbox': ['0.000008', '0.546224', '0.349488', '0.999980']},
#  {'dataset': 'validation',
#   'label': 'Toilet',
#   'id': '539e0871494dea5d',
#   'bbox': ['0.201278', '0.815655', '0.000000', '1.000000']}]

# %%
df = pd.DataFrame(img_details)
df
# Out:
#        dataset    label                id  \
# 0   validation  Bathtub  3f66fdf9688514d4
# 1   validation  Bathtub  2f2039140c8b1f2b
# 2   validation  Bathtub  cd727c5e0d2cfc1b
# 3   validation  Bathtub  15348e4f2c7ebe0f
# 4   validation  Bathtub  789cc0283c0e18af
# 5   validation  Bathtub  784bba5f12ee7c35
# 6   validation  Bathtub  eccb080e57b2aac5
# 7   validation  Bathtub  2f0a18a409d5a769
# 8   validation  Bathtub  8e562fee6ff208f7
# 9   validation  Bathtub  822f20d881eebeb9
# 10  validation  Bathtub  d7d469cb4c7e8cd2
# 11  validation  Bathtub  11dcac4ca5923a58
# 12  validation  Bathtub  ddd3f96ff7f0bc78
# 13  validation  Bathtub  837b3d11ff02f116
# 14  validation   Toilet  b2dc8e2437e8803f
# 15  validation   Toilet  36d8c654fba5f337
# 16  validation   Toilet  217b95a71cb220f8
# 17  validation   Toilet  3a511ef0f68cc438
# 18  validation   Toilet  42298c9659ce6603
# 19  validation   Toilet  17f698ec871569ca
# 20  validation   Toilet  c7312a8b436f5e90
# 21  validation   Toilet  b3a65783709539de
# 22  validation   Toilet  47ab0e73c33bdefd
# 23  validation   Toilet  0d0719cfd8e417b7
# 24  validation   Toilet  d60e1c25e87d8b45
# 25  validation   Toilet  f90eac5444f62b19
# 26  validation   Toilet  2ff2bb609a057f7a
# 27  validation   Toilet  be84a3da54658167
# 28  validation   Toilet  2f0a18a409d5a769
# 29  validation   Toilet  c1eefc708000b69f
# 30  validation   Toilet  7c2825a3d8e0ed29
# 31  validation   Toilet  40a69f79da2aeaaa
# 32  validation   Toilet  85ccc93d1f941931
# 33  validation   Toilet  eaa75967cbc70ac1
# 34  validation   Toilet  3454c87a14067798
# 35  validation   Toilet  e108d68162990dfb
# 36  validation   Toilet  e6e05b56799fefba
# 37  validation   Toilet  539e0871494dea5d
# 38  validation   Toilet  b821cc12eede040e
#
#                                   file_name
# 0   validation/Bathtub/3f66fdf9688514d4.jpg
# 1   validation/Bathtub/2f2039140c8b1f2b.jpg
# 2   validation/Bathtub/cd727c5e0d2cfc1b.jpg
# 3   validation/Bathtub/15348e4f2c7ebe0f.jpg
# 4   validation/Bathtub/789cc0283c0e18af.jpg
# 5   validation/Bathtub/784bba5f12ee7c35.jpg
# 6   validation/Bathtub/eccb080e57b2aac5.jpg
# 7   validation/Bathtub/2f0a18a409d5a769.jpg
# 8   validation/Bathtub/8e562fee6ff208f7.jpg
# 9   validation/Bathtub/822f20d881eebeb9.jpg
# 10  validation/Bathtub/d7d469cb4c7e8cd2.jpg
# 11  validation/Bathtub/11dcac4ca5923a58.jpg
# 12  validation/Bathtub/ddd3f96ff7f0bc78.jpg
# 13  validation/Bathtub/837b3d11ff02f116.jpg
# 14   validation/Toilet/b2dc8e2437e8803f.jpg
# 15   validation/Toilet/36d8c654fba5f337.jpg
# 16   validation/Toilet/217b95a71cb220f8.jpg
# 17   validation/Toilet/3a511ef0f68cc438.jpg
# 18   validation/Toilet/42298c9659ce6603.jpg
# 19   validation/Toilet/17f698ec871569ca.jpg
# 20   validation/Toilet/c7312a8b436f5e90.jpg
# 21   validation/Toilet/b3a65783709539de.jpg
# 22   validation/Toilet/47ab0e73c33bdefd.jpg
# 23   validation/Toilet/0d0719cfd8e417b7.jpg
# 24   validation/Toilet/d60e1c25e87d8b45.jpg
# 25   validation/Toilet/f90eac5444f62b19.jpg
# 26   validation/Toilet/2ff2bb609a057f7a.jpg
# 27   validation/Toilet/be84a3da54658167.jpg
# 28   validation/Toilet/2f0a18a409d5a769.jpg
# 29   validation/Toilet/c1eefc708000b69f.jpg
# 30   validation/Toilet/7c2825a3d8e0ed29.jpg
# 31   validation/Toilet/40a69f79da2aeaaa.jpg
# 32   validation/Toilet/85ccc93d1f941931.jpg
# 33   validation/Toilet/eaa75967cbc70ac1.jpg
# 34   validation/Toilet/3454c87a14067798.jpg
# 35   validation/Toilet/e108d68162990dfb.jpg
# 36   validation/Toilet/e6e05b56799fefba.jpg
# 37   validation/Toilet/539e0871494dea5d.jpg
# 38   validation/Toilet/b821cc12eede040e.jpg

# %% [markdown]
# I should write a function which:
# - Gets my image IDs
# - Matches them with their details in the annotations csv
# - Saves their file name

# %%
val_annot = pd.read_csv("validation-annotations-bbox.csv")
val_annot
# Out:
#                  ImageID    Source  LabelName  Confidence      XMin      XMax  \
# 0       0001eeaf4aed83f9  freeform   /m/0cmf2           1  0.022464  0.964178
# 1       000595fe6fee6369  freeform   /m/02wbm           1  0.000000  1.000000
# 2       000595fe6fee6369  freeform   /m/02xwb           1  0.141030  0.180277
# 3       000595fe6fee6369  freeform   /m/02xwb           1  0.213781  0.253028
# 4       000595fe6fee6369  freeform   /m/02xwb           1  0.232926  0.288447
# ...                  ...       ...        ...         ...       ...       ...
# 204616  ffff21932da3ed01  freeform  /m/03fp41           1  0.177790  0.710296
# 204617  ffff21932da3ed01  freeform   /m/05s2s           1  0.000000  0.031963
# 204618  ffff21932da3ed01  freeform  /m/0c9ph5           1  0.323775  0.409382
# 204619  ffff21932da3ed01  freeform  /m/0c9ph5           1  0.540223  0.624863
# 204620  ffff21932da3ed01  freeform   /m/0cgh4           1  0.002521  1.000000
#
#             YMin      YMax  IsOccluded  IsTruncated  IsGroupOf  IsDepiction  \
# 0       0.070656  0.800164           0            0          0            0
# 1       0.000233  1.000000           0            0          1            0
# 2       0.676262  0.732455           0            0          0            0
# 3       0.298764  0.354956           1            0          0            0
# 4       0.488954  0.545146           1            0          0            0
# ...          ...       ...         ...          ...        ...          ...
# 204616  0.412302  0.578570           0            0          1            0
# 204617  0.502994  0.562275           1            1          0            0
# 204618  0.464495  0.554111           0            0          1            0
# 204619  0.493633  0.577892           1            0          1            0
# 204620  0.000000  0.998685           0            0          0            0
#
#         IsInside
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 204616         0
# 204617         0
# 204618         0
# 204619         0
# 204620         1
#
# [204621 rows x 13 columns]

# %%
classes = pd.read_csv("class-descriptions-boxable.csv", names=["id", "ClassName"])
classes
# Out:
#               id   ClassName
# 0      /m/011k07    Tortoise
# 1    /m/011q46kg   Container
# 2      /m/012074      Magpie
# 3      /m/0120dh  Sea turtle
# 4      /m/01226z    Football
# ..           ...         ...
# 596     /m/0qmmr  Wheelchair
# 597   /m/0wdt60w  Rugby ball
# 598      /m/0xfy   Armadillo
# 599     /m/0xzly     Maracas
# 600     /m/0zvk5      Helmet
#
# [601 rows x 2 columns]

# %%
# %%time
# Create classname column on annotations which converts label codes to string labels
val_annot["ClassName"] = val_annot["LabelName"].map(classes.set_index("id")["ClassName"])
val_annot["ClassName"]
# Out:
# CPU times: user 24.3 ms, sys: 3.51 ms, total: 27.8 ms
# Wall time: 26.4 ms
# 0           Airplane
# 1               Food
# 2              Fruit
# 3              Fruit
# 4              Fruit
#              ...
# 204616    Houseplant
# 204617         Plant
# 204618        Flower
# 204619        Flower
# 204620      Building
# Name: ClassName, Length: 204621, dtype: object

# %% [markdown]
# # Move all images into one file

# %%
# Take these and move them into one file
img_files[:3]
# Out:
# ['validation/Bathtub/3f66fdf9688514d4.jpg',
#  'validation/Bathtub/2f2039140c8b1f2b.jpg',
#  'validation/Bathtub/cd727c5e0d2cfc1b.jpg']

# %%
# Make directory with images
os.mkdir("images")

# %%
# Copy images files to images
import shutil
for image in img_files:
    shutil.copy2(image, "images")

# %%
len(os.listdir("images")), len(img_files)
# Out:
# (38, 39)

# %%
len([i.split("/")[2] for i in img_files])
# Out:
# 39

# %%
len(np.unique([i.split("/")[2] for i in img_files]))
# Out:
# 38

# %%
# Make list of images we have and split them off the dataframe with all the label information
my_images = [os.path.splitext(img_name)[0] for img_name in os.listdir("images")]
my_images
# Out:
# ['b2dc8e2437e8803f',
#  '36d8c654fba5f337',
#  '217b95a71cb220f8',
#  '3f66fdf9688514d4',
#  '3a511ef0f68cc438',
#  '42298c9659ce6603',
#  '17f698ec871569ca',
#  'c7312a8b436f5e90',
#  'b3a65783709539de',
#  '2f2039140c8b1f2b',
#  'cd727c5e0d2cfc1b',
#  '47ab0e73c33bdefd',
#  '0d0719cfd8e417b7',
#  '15348e4f2c7ebe0f',
#  'd60e1c25e87d8b45',
#  '789cc0283c0e18af',
#  'f90eac5444f62b19',
#  '2ff2bb609a057f7a',
#  'be84a3da54658167',
#  '784bba5f12ee7c35',
#  'eccb080e57b2aac5',
#  '2f0a18a409d5a769',
#  'c1eefc708000b69f',
#  '8e562fee6ff208f7',
#  '7c2825a3d8e0ed29',
#  '822f20d881eebeb9',
#  'd7d469cb4c7e8cd2',
#  '40a69f79da2aeaaa',
#  '85ccc93d1f941931',
#  '11dcac4ca5923a58',
#  'eaa75967cbc70ac1',
#  'ddd3f96ff7f0bc78',
#  '3454c87a14067798',
#  'e108d68162990dfb',
#  'e6e05b56799fefba',
#  '539e0871494dea5d',
#  'b821cc12eede040e',
#  '837b3d11ff02f116']

# %%
subset
# Out:
# ['Toilet',
#  'Swimming_pool',
#  'Bed',
#  'Biliard_table',
#  'Sink',
#  'Fountain',
#  'Oven',
#  'Ceiling_fan',
#  'Television',
#  'Microwave_oven',
#  'Gas_stove',
#  'Refrigerator',
#  'Kitchen_&_dining_room_table',
#  'Washing_machine',
#  'Bathtub',
#  'Stairs',
#  'Fireplace',
#  'Pillow',
#  'Mirror',
#  'Shower',
#  'Couch',
#  'Countertop',
#  'Coffeemaker',
#  'Dishwasher',
#  'Sofa_bed',
#  'Tree_house',
#  'Towel',
#  'Porch',
#  'Wine_rack',
#  'Jacuzzi']

# %%
# Make sure we only get the images we're concerned about
my_images_df = val_annot[val_annot["ImageID"].isin(my_images) & val_annot["ClassName"].isin(subset)]
my_images_df.head()
# Out:
#                 ImageID    Source  LabelName  Confidence      XMin      XMax  \
# 10797  0d0719cfd8e417b7  freeform   /m/09g1w           1  0.093371  0.986232
# 14593  11dcac4ca5923a58  freeform  /m/03dnzn           1  0.360645  0.999988
# 17325  15348e4f2c7ebe0f  freeform  /m/03dnzn           1  0.087330  0.999973
# 17329  15348e4f2c7ebe0f  freeform  /m/065h6l           1  0.090833  1.000000
# 19543  17f698ec871569ca  freeform   /m/09g1w           1  0.160562  0.475538
#
#            YMin      YMax  IsOccluded  IsTruncated  IsGroupOf  IsDepiction  \
# 10797  0.189984  0.965806           0            0          0            0
# 14593  0.000000  1.000000           0            1          0            0
# 17325  0.600616  0.999962           0            0          0            0
# 17329  0.600928  1.000000           0            0          0            0
# 19543  0.181890  0.847251           0            0          0            0
#
#        IsInside ClassName
# 10797         0    Toilet
# 14593         0   Bathtub
# 17325         0   Bathtub
# 17329         0   Jacuzzi
# 19543         0    Toilet

# %%
my_images_df.columns
# Out:
# Index(['ImageID', 'Source', 'LabelName', 'Confidence', 'XMin', 'XMax', 'YMin',
#        'YMax', 'IsOccluded', 'IsTruncated', 'IsGroupOf', 'IsDepiction',
#        'IsInside', 'ClassName'],
#       dtype='object')

# %%
pd.Categorical(my_images_df.ClassName).codes
# Out:
# array([3, 0, 0, 1, 3, 3, 3, 0, 3, 0, 3, 3, 3, 3, 2, 3, 0, 3, 3, 3, 3, 0,
#        0, 3, 0, 1, 0, 3, 0, 0, 3, 3, 3, 3, 3, 2, 2, 2, 3, 3, 0, 2, 3, 0,
#        1, 0, 3, 3, 3, 0, 1, 3], dtype=int8)

# %%
my_images_df[my_images_df["ImageID"] == "c7312a8b436f5e90"]["ClassName"].values
# Out:
# array(['Sink', 'Sink', 'Sink', 'Toilet', 'Toilet'], dtype=object)

# %%
my_images_df[my_images_df["ImageID"] == "c7312a8b436f5e90"][["XMin", "XMax", "YMin", "YMax"]].values
# Out:
# array([[0.238995, 0.372361, 0.778648, 0.871384],
#        [0.461353, 0.615221, 0.322836, 0.441359],
#        [0.782433, 0.921636, 0.850595, 0.936918],
#        [0.483064, 0.58323 , 0.148464, 0.254009],
#        [0.756245, 0.872021, 0.377751, 0.570644]])

# %%
len(my_images_df)
# Out:
# 52

# %%
my_images_df["ImageID"].value_counts()
# Out:
# c7312a8b436f5e90    5
# 17f698ec871569ca    2
# 8e562fee6ff208f7    2
# d60e1c25e87d8b45    2
# 2f0a18a409d5a769    2
# 3454c87a14067798    2
# eccb080e57b2aac5    2
# 3a511ef0f68cc438    2
# 822f20d881eebeb9    2
# 15348e4f2c7ebe0f    2
# d7d469cb4c7e8cd2    2
# 85ccc93d1f941931    1
# b821cc12eede040e    1
# 11dcac4ca5923a58    1
# 217b95a71cb220f8    1
# 36d8c654fba5f337    1
# 47ab0e73c33bdefd    1
# eaa75967cbc70ac1    1
# 2ff2bb609a057f7a    1
# 3f66fdf9688514d4    1
# 0d0719cfd8e417b7    1
# ddd3f96ff7f0bc78    1
# c1eefc708000b69f    1
# f90eac5444f62b19    1
# 2f2039140c8b1f2b    1
# be84a3da54658167    1
# 42298c9659ce6603    1
# cd727c5e0d2cfc1b    1
# b3a65783709539de    1
# 7c2825a3d8e0ed29    1
# e108d68162990dfb    1
# 789cc0283c0e18af    1
# e6e05b56799fefba    1
# 784bba5f12ee7c35    1
# 40a69f79da2aeaaa    1
# 837b3d11ff02f116    1
# b2dc8e2437e8803f    1
# 539e0871494dea5d    1
# Name: ImageID, dtype: int64

# %%
# %%time
# Create images labels setup in detectron2 style
img_dicts = []
for i, img in enumerate(my_images):
    file_path = "images/" + img + ".jpg"
    img_data = my_images_df[my_images_df["ImageID"] == img]
    img_label = img_data["ClassName"].values
    bboxes = img_data[["XMin", "XMax", "YMin", "YMax"]].values
    img_dict = {"file_path": file_path,
                "img_label": img_label,
                "bboxes": bboxes}
    img_dicts.append(img_dict)
img_dicts
# Out:
# CPU times: user 63.7 ms, sys: 7.1 ms, total: 70.8 ms
# Wall time: 66.6 ms
# [{'file_path': 'images/b2dc8e2437e8803f.jpg',
#   'img_label': array(['Toilet'], dtype=object),
#   'bboxes': array([[0.337954, 0.695044, 0.258797, 0.857483]])},
#  {'file_path': 'images/36d8c654fba5f337.jpg',
#   'img_label': array(['Toilet'], dtype=object),
#   'bboxes': array([[0.063034, 0.805088, 0.      , 0.697051]])},
#  {'file_path': 'images/217b95a71cb220f8.jpg',
#   'img_label': array(['Toilet'], dtype=object),
#   'bboxes': array([[0.438669, 0.602654, 0.449081, 0.532643]])},
#  {'file_path': 'images/3f66fdf9688514d4.jpg',
#   'img_label': array(['Bathtub'], dtype=object),
#   'bboxes': array([[0.050368, 0.933495, 0.250992, 1.      ]])},
#  {'file_path': 'images/3a511ef0f68cc438.jpg',
#   'img_label': array(['Sink', 'Toilet'], dtype=object),
#   'bboxes': array([[0.22748 , 0.493562, 0.625067, 0.78379 ],
#          [0.124107, 0.338616, 0.755953, 0.978802]])},
#  {'file_path': 'images/42298c9659ce6603.jpg',
#   'img_label': array(['Toilet'], dtype=object),
#   'bboxes': array([[0.301737, 0.792065, 0.190453, 0.83854 ]])},
#  {'file_path': 'images/17f698ec871569ca.jpg',
#   'img_label': array(['Toilet', 'Toilet'], dtype=object),
#   'bboxes': array([[0.160562, 0.475538, 0.18189 , 0.847251],
#          [0.620177, 0.930982, 0.182484, 0.813342]])},
#  {'file_path': 'images/c7312a8b436f5e90.jpg',
#   'img_label': array(['Sink', 'Sink', 'Sink', 'Toilet', 'Toilet'], dtype=object),
#   'bboxes': array([[0.238995, 0.372361, 0.778648, 0.871384],
#          [0.461353, 0.615221, 0.322836, 0.441359],
#          [0.782433, 0.921636, 0.850595, 0.936918],
#          [0.483064, 0.58323 , 0.148464, 0.254009],
#          [0.756245, 0.872021, 0.377751, 0.570644]])},
#  {'file_path': 'images/b3a65783709539de.jpg',
#   'img_label': array(['Toilet'], dtype=object),
#   'bboxes': array([[0.184904, 0.846895, 0.060172, 0.961222]])},
#  {'file_path': 'images/2f2039140c8b1f2b.jpg',
#   'img_label': array(['Bathtub'], dtype=object),
#   'bboxes': array([[0., 1., 0., 1.]])},
#  {'file_path': 'images/cd727c5e0d2cfc1b.jpg',
#   'img_label': array(['Bathtub'], dtype=object),
#   'bboxes': array([[0.048442, 0.980496, 0.427911, 0.806723]])},
#  {'file_path': 'images/47ab0e73c33bdefd.jpg',
#   'img_label': array(['Toilet'], dtype=object),
#   'bboxes': array([[0.197381, 0.922556, 0.468605, 0.829202]])},
#  {'file_path': 'images/0d0719cfd8e417b7.jpg',
#   'img_label': array(['Toilet'], dtype=object),
#   'bboxes': array([[0.093371, 0.986232, 0.189984, 0.965806]])},
#  {'file_path': 'images/15348e4f2c7ebe0f.jpg',
#   'img_label': array(['Bathtub', 'Jacuzzi'], dtype=object),
#   'bboxes': array([[0.08733 , 0.999973, 0.600616, 0.999962],
#          [0.090833, 1.      , 0.600928, 1.      ]])},
#  {'file_path': 'images/d60e1c25e87d8b45.jpg',
#   'img_label': array(['Sink', 'Toilet'], dtype=object),
#   'bboxes': array([[0.      , 0.823265, 0.315739, 0.975746],
#          [0.405653, 1.      , 0.146613, 0.626838]])},
#  {'file_path': 'images/789cc0283c0e18af.jpg',
#   'img_label': array(['Bathtub'], dtype=object),
#   'bboxes': array([[0.039686, 0.948718, 0.119581, 1.      ]])},
#  {'file_path': 'images/f90eac5444f62b19.jpg',
#   'img_label': array(['Toilet'], dtype=object),
#   'bboxes': array([[0.405385, 0.896555, 0.624074, 1.      ]])},
#  {'file_path': 'images/2ff2bb609a057f7a.jpg',
#   'img_label': array(['Toilet'], dtype=object),
#   'bboxes': array([[0.182173, 0.798462, 0.273742, 0.942715]])},
#  {'file_path': 'images/be84a3da54658167.jpg',
#   'img_label': array(['Toilet'], dtype=object),
#   'bboxes': array([[0.246185, 0.776473, 0.72837 , 1.      ]])},
#  {'file_path': 'images/784bba5f12ee7c35.jpg',
#   'img_label': array(['Bathtub'], dtype=object),
#   'bboxes': array([[0., 1., 0., 1.]])},
#  {'file_path': 'images/eccb080e57b2aac5.jpg',
#   'img_label': array(['Bathtub', 'Jacuzzi'], dtype=object),
#   'bboxes': array([[0.303341, 0.905829, 0.470852, 0.999948],
#          [0.301963, 0.90845 , 0.472029, 0.999245]])},
#  {'file_path': 'images/2f0a18a409d5a769.jpg',
#   'img_label': array(['Bathtub', 'Toilet'], dtype=object),
#   'bboxes': array([[1.57351e-01, 1.00000e+00, 3.28732e-01, 9.27573e-01],
#          [8.00000e-06, 5.46224e-01, 3.49488e-01, 9.99980e-01]])},
#  {'file_path': 'images/c1eefc708000b69f.jpg',
#   'img_label': array(['Toilet'], dtype=object),
#   'bboxes': array([[0.201985, 0.772443, 0.097975, 0.983168]])},
#  {'file_path': 'images/8e562fee6ff208f7.jpg',
#   'img_label': array(['Bathtub', 'Bathtub'], dtype=object),
#   'bboxes': array([[0.013755, 0.513952, 0.476118, 0.99998 ],
#          [0.494666, 0.983858, 0.546178, 1.      ]])},
#  {'file_path': 'images/7c2825a3d8e0ed29.jpg',
#   'img_label': array(['Toilet'], dtype=object),
#   'bboxes': array([[0.207057, 0.415161, 0.809775, 0.999841]])},
#  {'file_path': 'images/822f20d881eebeb9.jpg',
#   'img_label': array(['Bathtub', 'Jacuzzi'], dtype=object),
#   'bboxes': array([[0.      , 1.      , 0.181437, 0.963113],
#          [0.      , 1.      , 0.170432, 0.970351]])},
#  {'file_path': 'images/d7d469cb4c7e8cd2.jpg',
#   'img_label': array(['Bathtub', 'Jacuzzi'], dtype=object),
#   'bboxes': array([[8.10000e-05, 9.99159e-01, 4.35396e-01, 1.00000e+00],
#          [0.00000e+00, 1.00000e+00, 4.36194e-01, 1.00000e+00]])},
#  {'file_path': 'images/40a69f79da2aeaaa.jpg',
#   'img_label': array(['Toilet'], dtype=object),
#   'bboxes': array([[0.01417 , 0.473459, 0.348211, 0.999983]])},
#  {'file_path': 'images/85ccc93d1f941931.jpg',
#   'img_label': array(['Toilet'], dtype=object),
#   'bboxes': array([[0.369258, 0.746107, 0.152027, 1.      ]])},
#  {'file_path': 'images/11dcac4ca5923a58.jpg',
#   'img_label': array(['Bathtub'], dtype=object),
#   'bboxes': array([[0.360645, 0.999988, 0.      , 1.      ]])},
#  {'file_path': 'images/eaa75967cbc70ac1.jpg',
#   'img_label': array(['Toilet'], dtype=object),
#   'bboxes': array([[0.095922, 0.870645, 0.124023, 0.57018 ]])},
#  {'file_path': 'images/ddd3f96ff7f0bc78.jpg',
#   'img_label': array(['Bathtub'], dtype=object),
#   'bboxes': array([[0.251883, 0.976808, 0.460918, 1.      ]])},
#  {'file_path': 'images/3454c87a14067798.jpg',
#   'img_label': array(['Toilet', 'Toilet'], dtype=object),
#   'bboxes': array([[0.077027, 0.306008, 0.811938, 1.      ],
#          [0.583791, 0.820996, 0.810397, 0.999875]])},
#  {'file_path': 'images/e108d68162990dfb.jpg',
#   'img_label': array(['Toilet'], dtype=object),
#   'bboxes': array([[0.36077 , 0.656517, 0.410382, 0.886037]])},
#  {'file_path': 'images/e6e05b56799fefba.jpg',
#   'img_label': array(['Toilet'], dtype=object),
#   'bboxes': array([[0.059556, 0.956108, 0.      , 0.507183]])},
#  {'file_path': 'images/539e0871494dea5d.jpg',
#   'img_label': array(['Toilet'], dtype=object),
#   'bboxes': array([[0.201278, 0.815655, 0.      , 1.      ]])},
#  {'file_path': 'images/b821cc12eede040e.jpg',
#   'img_label': array(['Toilet'], dtype=object),
#   'bboxes': array([[0.520803, 0.940757, 0.603367, 0.988894]])},
#  {'file_path': 'images/837b3d11ff02f116.jpg',
#   'img_label': array(['Bathtub'], dtype=object),
#   'bboxes': array([[0.      , 0.669035, 0.372941, 1.      ]])}]

# %%
# %%time
multiple = my_images_df[my_images_df["ImageID"] == "d60e1c25e87d8b45"].reset_index()
for i in range(len(multiple)):
    print(multiple.loc[i])
# Out:
# index                    172106
# ImageID        d60e1c25e87d8b45
# Source                 freeform
# LabelName             /m/0130jx
# Confidence                    1
# XMin                          0
# XMax                   0.823265
# YMin                   0.315739
# YMax                   0.975746
# IsOccluded                    0
# IsTruncated                   0
# IsGroupOf                     0
# IsDepiction                   0
# IsInside                      0
# ClassName                  Sink
# Name: 0, dtype: object
# index                    172112
# ImageID        d60e1c25e87d8b45
# Source                 freeform
# LabelName              /m/09g1w
# Confidence                    1
# XMin                   0.405653
# XMax                          1
# YMin                   0.146613
# YMax                   0.626838
# IsOccluded                    1
# IsTruncated                   0
# IsGroupOf                     0
# IsDepiction                   0
# IsInside                      0
# ClassName                Toilet
# Name: 1, dtype: object
# CPU times: user 7.49 ms, sys: 0 ns, total: 7.49 ms
# Wall time: 5.9 ms

# %%
# %%time
category_ids = pd.Categorical(my_images_df["ClassName"]).codes
my_images_df.loc[:, "ClassID"] = category_ids
my_images_df.head()
# Out:
# CPU times: user 2.4 ms, sys: 4.48 ms, total: 6.88 ms
# Wall time: 6.35 ms
# /home/ubuntu/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/pandas/core/indexing.py:845: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ubuntu/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/pandas/core/indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
#                 ImageID    Source  LabelName  Confidence      XMin      XMax  \
# 10797  0d0719cfd8e417b7  freeform   /m/09g1w           1  0.093371  0.986232
# 14593  11dcac4ca5923a58  freeform  /m/03dnzn           1  0.360645  0.999988
# 17325  15348e4f2c7ebe0f  freeform  /m/03dnzn           1  0.087330  0.999973
# 17329  15348e4f2c7ebe0f  freeform  /m/065h6l           1  0.090833  1.000000
# 19543  17f698ec871569ca  freeform   /m/09g1w           1  0.160562  0.475538
#
#            YMin      YMax  IsOccluded  IsTruncated  IsGroupOf  IsDepiction  \
# 10797  0.189984  0.965806           0            0          0            0
# 14593  0.000000  1.000000           0            1          0            0
# 17325  0.600616  0.999962           0            0          0            0
# 17329  0.600928  1.000000           0            0          0            0
# 19543  0.181890  0.847251           0            0          0            0
#
#        IsInside ClassName  ClassID
# 10797         0    Toilet        3
# 14593         0   Bathtub        0
# 17325         0   Bathtub        0
# 17329         0   Jacuzzi        1
# 19543         0    Toilet        3

# %%
img_dicts[0]
# Out:
# {'file_path': 'images/b2dc8e2437e8803f.jpg',
#  'img_label': array(['Toilet'], dtype=object),
#  'bboxes': array([[0.337954, 0.695044, 0.258797, 0.857483]])}

# %%
# %%time
# Create images labels setup in detectron2 style
img_dicts = []
for img in my_images:
    record = {}
    # Add image metadata
    filename = "images/" + img + ".jpg"
    img_data = my_images_df[my_images_df["ImageID"] == img].reset_index()
    
    record["file_name"] = filename
    record["image_id"] = img
    # TODO - use cv2
    record["height"] = 0
    record["width"] = 0
    
    # Create annotations list (contains labels of images)
    annotations = []
    for i in range(len(img_data)):
        img_label = img_data.loc[i]["ClassName"]
        category_id = img_data.loc[i]["ClassID"]
        #print(f"label: {img_label}")
        bbox = [img_data.loc[i][["XMin", "XMax", "YMin", "YMax"]].values]
        obj = {
            "bbox": bbox,
            "bbox_mode": 0, # TODO
            #"img_label": img_label, # not needed
            "category_id": category_id, 
             #"segmentation": ["poly"], # not needed for bounding boxes
             #"iscrowd": 0 # not included as per detectron2 docs sure of this  
        }
        annotations.append(obj)
        #print(annotations)
    record["annotations"] = annotations
    img_dicts.append(record)
img_dicts
# Out:
# CPU times: user 170 ms, sys: 0 ns, total: 170 ms
# Wall time: 166 ms
# [{'file_name': 'images/b2dc8e2437e8803f.jpg',
#   'image_id': 'b2dc8e2437e8803f',
#   'height': 0,
#   'width': 0,
#   'annotations': [{'bbox': [array([0.337954, 0.695044, 0.258797, 0.857483], dtype=object)],
#     'bbox_mode': 0,
#     'category_id': 3}]},
#  {'file_name': 'images/36d8c654fba5f337.jpg',
#   'image_id': '36d8c654fba5f337',
#   'height': 0,
#   'width': 0,
#   'annotations': [{'bbox': [array([0.063034, 0.805088, 0.0, 0.697051], dtype=object)],
#     'bbox_mode': 0,
#     'category_id': 3}]},
#  {'file_name': 'images/217b95a71cb220f8.jpg',
#   'image_id': '217b95a71cb220f8',
#   'height': 0,
#   'width': 0,
#   'annotations': [{'bbox': [array([0.438669, 0.602654, 0.44908100000000006, 0.532643], dtype=object)],
#     'bbox_mode': 0,
#     'category_id': 3}]},
#  {'file_name': 'images/3f66fdf9688514d4.jpg',
#   'image_id': '3f66fdf9688514d4',
#   'height': 0,
#   'width': 0,
#   'annotations': [{'bbox': [array([0.050368, 0.9334950000000001, 0.250992, 1.0], dtype=object)],
#     'bbox_mode': 0,
#     'category_id': 0}]},
#  {'file_name': 'images/3a511ef0f68cc438.jpg',
#   'image_id': '3a511ef0f68cc438',
#   'height': 0,
#   'width': 0,
#   'annotations': [{'bbox': [array([0.22748000000000002, 0.493562, 0.625067, 0.78379], dtype=object)],
#     'bbox_mode': 0,
#     'category_id': 2},
#    {'bbox': [array([0.124107, 0.338616, 0.755953, 0.9788020000000001], dtype=object)],
#     'bbox_mode': 0,
#     'category_id': 3}]},
#  {'file_name': 'images/42298c9659ce6603.jpg',
#   'image_id': '42298c9659ce6603',
#   'height': 0,
#   'width': 0,
#   'annotations': [{'bbox': [array([0.301737, 0.792065, 0.19045299999999998, 0.83854], dtype=object)],
#     'bbox_mode': 0,
#     'category_id': 3}]},
#  {'file_name': 'images/17f698ec871569ca.jpg',
#   'image_id': '17f698ec871569ca',
#   'height': 0,
#   'width': 0,
#   'annotations': [{'bbox': [array([0.16056199999999998, 0.475538, 0.18189, 0.847251], dtype=object)],
#     'bbox_mode': 0,
#     'category_id': 3},
#    {'bbox': [array([0.6201770000000001, 0.930982, 0.18248399999999998, 0.813342],
#            dtype=object)],
#     'bbox_mode': 0,
#     'category_id': 3}]},
#  {'file_name': 'images/c7312a8b436f5e90.jpg',
#   'image_id': 'c7312a8b436f5e90',
#   'height': 0,
#   'width': 0,
#   'annotations': [{'bbox': [array([0.23899499999999999, 0.372361, 0.778648, 0.871384], dtype=object)],
#     'bbox_mode': 0,
#     'category_id': 2},
#    {'bbox': [array([0.46135299999999996, 0.615221, 0.322836, 0.441359], dtype=object)],
#     'bbox_mode': 0,
#     'category_id': 2},
#    {'bbox': [array([0.782433, 0.921636, 0.8505950000000001, 0.936918], dtype=object)],
#     'bbox_mode': 0,
#     'category_id': 2},
#    {'bbox': [array([0.48306400000000005, 0.58323, 0.148464, 0.25400900000000004],
#            dtype=object)],
#     'bbox_mode': 0,
#     'category_id': 3},
#    {'bbox': [array([0.756245, 0.8720209999999999, 0.377751, 0.5706439999999999],
#            dtype=object)],
#     'bbox_mode': 0,
#     'category_id': 3}]},
#  {'file_name': 'images/b3a65783709539de.jpg',
#   'image_id': 'b3a65783709539de',
#   'height': 0,
#   'width': 0,
#   'annotations': [{'bbox': [array([0.18490399999999999, 0.8468950000000001, 0.060172,
#             0.9612219999999999], dtype=object)],
#     'bbox_mode': 0,
#     'category_id': 3}]},
#  {'file_name': 'images/2f2039140c8b1f2b.jpg',
#   'image_id': '2f2039140c8b1f2b',
#   'height': 0,
#   'width': 0,
#   'annotations': [{'bbox': [array([0.0, 1.0, 0.0, 1.0], dtype=object)],
#     'bbox_mode': 0,
#     'category_id': 0}]},
#  {'file_name': 'images/cd727c5e0d2cfc1b.jpg',
#   'image_id': 'cd727c5e0d2cfc1b',
#   'height': 0,
#   'width': 0,
#   'annotations': [{'bbox': [array([0.048442, 0.9804959999999999, 0.427911, 0.806723], dtype=object)],
#     'bbox_mode': 0,
#     'category_id': 0}]},
#  {'file_name': 'images/47ab0e73c33bdefd.jpg',
#   'image_id': '47ab0e73c33bdefd',
#   'height': 0,
#   'width': 0,
#   'annotations': [{'bbox': [array([0.197381, 0.9225559999999999, 0.468605, 0.829202], dtype=object)],
#     'bbox_mode': 0,
#     'category_id': 3}]},
#  {'file_name': 'images/0d0719cfd8e417b7.jpg',
#   'image_id': '0d0719cfd8e417b7',
#   'height': 0,
#   'width': 0,
#   'annotations': [{'bbox': [array([0.09337100000000001, 0.986232, 0.189984, 0.9658059999999999],
#            dtype=object)],
#     'bbox_mode': 0,
#     'category_id': 3}]},
#  {'file_name': 'images/15348e4f2c7ebe0f.jpg',
#   'image_id': '15348e4f2c7ebe0f',
#   'height': 0,
#   'width': 0,
#   'annotations': [{'bbox': [array([0.08732999999999999, 0.999973, 0.600616, 0.9999620000000001],
#            dtype=object)],
#     'bbox_mode': 0,
#     'category_id': 0},
#    {'bbox': [array([0.09083300000000001, 1.0, 0.600928, 1.0], dtype=object)],
#     'bbox_mode': 0,
#     'category_id': 1}]},
#  {'file_name': 'images/d60e1c25e87d8b45.jpg',
#   'image_id': 'd60e1c25e87d8b45',
#   'height': 0,
#   'width': 0,
#   'annotations': [{'bbox': [array([0.0, 0.8232649999999999, 0.315739, 0.9757459999999999],
#            dtype=object)],
#     'bbox_mode': 0,
#     'category_id': 2},
#    {'bbox': [array([0.40565300000000004, 1.0, 0.14661300000000002, 0.626838],
#            dtype=object)],
#     'bbox_mode': 0,
#     'category_id': 3}]},
#  {'file_name': 'images/789cc0283c0e18af.jpg',
#   'image_id': '789cc0283c0e18af',
#   'height': 0,
#   'width': 0,
#   'annotations': [{'bbox': [array([0.039686, 0.9487180000000001, 0.11958099999999999, 1.0],
#            dtype=object)],
#     'bbox_mode': 0,
#     'category_id': 0}]},
#  {'file_name': 'images/f90eac5444f62b19.jpg',
#   'image_id': 'f90eac5444f62b19',
#   'height': 0,
#   'width': 0,
#   'annotations': [{'bbox': [array([0.405385, 0.8965549999999999, 0.624074, 1.0], dtype=object)],
#     'bbox_mode': 0,
#     'category_id': 3}]},
#  {'file_name': 'images/2ff2bb609a057f7a.jpg',
#   'image_id': '2ff2bb609a057f7a',
#   'height': 0,
#   'width': 0,
#   'annotations': [{'bbox': [array([0.182173, 0.798462, 0.273742, 0.942715], dtype=object)],
#     'bbox_mode': 0,
#     'category_id': 3}]},
#  {'file_name': 'images/be84a3da54658167.jpg',
#   'image_id': 'be84a3da54658167',
#   'height': 0,
#   'width': 0,
#   'annotations': [{'bbox': [array([0.246185, 0.776473, 0.72837, 1.0], dtype=object)],
#     'bbox_mode': 0,
#     'category_id': 3}]},
#  {'file_name': 'images/784bba5f12ee7c35.jpg',
#   'image_id': '784bba5f12ee7c35',
#   'height': 0,
#   'width': 0,
#   'annotations': [{'bbox': [array([0.0, 1.0, 0.0, 1.0], dtype=object)],
#     'bbox_mode': 0,
#     'category_id': 0}]},
#  {'file_name': 'images/eccb080e57b2aac5.jpg',
#   'image_id': 'eccb080e57b2aac5',
#   'height': 0,
#   'width': 0,
#   'annotations': [{'bbox': [array([0.30334099999999997, 0.9058290000000001, 0.47085200000000005,
#             0.999948], dtype=object)],
#     'bbox_mode': 0,
#     'category_id': 0},
#    {'bbox': [array([0.30196300000000004, 0.90845, 0.472029, 0.999245], dtype=object)],
#     'bbox_mode': 0,
#     'category_id': 1}]},
#  {'file_name': 'images/2f0a18a409d5a769.jpg',
#   'image_id': '2f0a18a409d5a769',
#   'height': 0,
#   'width': 0,
#   'annotations': [{'bbox': [array([0.157351, 1.0, 0.328732, 0.927573], dtype=object)],
#     'bbox_mode': 0,
#     'category_id': 0},
#    {'bbox': [array([8e-06, 0.5462239999999999, 0.349488, 0.99998], dtype=object)],
#     'bbox_mode': 0,
#     'category_id': 3}]},
#  {'file_name': 'images/c1eefc708000b69f.jpg',
#   'image_id': 'c1eefc708000b69f',
#   'height': 0,
#   'width': 0,
#   'annotations': [{'bbox': [array([0.201985, 0.772443, 0.097975, 0.983168], dtype=object)],
#     'bbox_mode': 0,
#     'category_id': 3}]},
#  {'file_name': 'images/8e562fee6ff208f7.jpg',
#   'image_id': '8e562fee6ff208f7',
#   'height': 0,
#   'width': 0,
#   'annotations': [{'bbox': [array([0.013755000000000002, 0.5139520000000001, 0.47611800000000004,
#             0.99998], dtype=object)],
#     'bbox_mode': 0,
#     'category_id': 0},
#    {'bbox': [array([0.494666, 0.983858, 0.5461779999999999, 1.0], dtype=object)],
#     'bbox_mode': 0,
#     'category_id': 0}]},
#  {'file_name': 'images/7c2825a3d8e0ed29.jpg',
#   'image_id': '7c2825a3d8e0ed29',
#   'height': 0,
#   'width': 0,
#   'annotations': [{'bbox': [array([0.20705700000000002, 0.41516099999999995, 0.809775, 0.999841],
#            dtype=object)],
#     'bbox_mode': 0,
#     'category_id': 3}]},
#  {'file_name': 'images/822f20d881eebeb9.jpg',
#   'image_id': '822f20d881eebeb9',
#   'height': 0,
#   'width': 0,
#   'annotations': [{'bbox': [array([0.0, 1.0, 0.181437, 0.9631129999999999], dtype=object)],
#     'bbox_mode': 0,
#     'category_id': 0},
#    {'bbox': [array([0.0, 1.0, 0.170432, 0.9703510000000001], dtype=object)],
#     'bbox_mode': 0,
#     'category_id': 1}]},
#  {'file_name': 'images/d7d469cb4c7e8cd2.jpg',
#   'image_id': 'd7d469cb4c7e8cd2',
#   'height': 0,
#   'width': 0,
#   'annotations': [{'bbox': [array([8.1e-05, 0.999159, 0.435396, 1.0], dtype=object)],
#     'bbox_mode': 0,
#     'category_id': 0},
#    {'bbox': [array([0.0, 1.0, 0.43619399999999997, 1.0], dtype=object)],
#     'bbox_mode': 0,
#     'category_id': 1}]},
#  {'file_name': 'images/40a69f79da2aeaaa.jpg',
#   'image_id': '40a69f79da2aeaaa',
#   'height': 0,
#   'width': 0,
#   'annotations': [{'bbox': [array([0.014169999999999999, 0.473459, 0.348211, 0.999983], dtype=object)],
#     'bbox_mode': 0,
#     'category_id': 3}]},
#  {'file_name': 'images/85ccc93d1f941931.jpg',
#   'image_id': '85ccc93d1f941931',
#   'height': 0,
#   'width': 0,
#   'annotations': [{'bbox': [array([0.369258, 0.746107, 0.152027, 1.0], dtype=object)],
#     'bbox_mode': 0,
#     'category_id': 3}]},
#  {'file_name': 'images/11dcac4ca5923a58.jpg',
#   'image_id': '11dcac4ca5923a58',
#   'height': 0,
#   'width': 0,
#   'annotations': [{'bbox': [array([0.360645, 0.9999879999999999, 0.0, 1.0], dtype=object)],
#     'bbox_mode': 0,
#     'category_id': 0}]},
#  {'file_name': 'images/eaa75967cbc70ac1.jpg',
#   'image_id': 'eaa75967cbc70ac1',
#   'height': 0,
#   'width': 0,
#   'annotations': [{'bbox': [array([0.09592200000000001, 0.8706450000000001, 0.12402300000000001,
#             0.57018], dtype=object)],
#     'bbox_mode': 0,
#     'category_id': 3}]},
#  {'file_name': 'images/ddd3f96ff7f0bc78.jpg',
#   'image_id': 'ddd3f96ff7f0bc78',
#   'height': 0,
#   'width': 0,
#   'annotations': [{'bbox': [array([0.25188299999999997, 0.976808, 0.46091800000000005, 1.0],
#            dtype=object)],
#     'bbox_mode': 0,
#     'category_id': 0}]},
#  {'file_name': 'images/3454c87a14067798.jpg',
#   'image_id': '3454c87a14067798',
#   'height': 0,
#   'width': 0,
#   'annotations': [{'bbox': [array([0.077027, 0.306008, 0.811938, 1.0], dtype=object)],
#     'bbox_mode': 0,
#     'category_id': 3},
#    {'bbox': [array([0.583791, 0.820996, 0.810397, 0.999875], dtype=object)],
#     'bbox_mode': 0,
#     'category_id': 3}]},
#  {'file_name': 'images/e108d68162990dfb.jpg',
#   'image_id': 'e108d68162990dfb',
#   'height': 0,
#   'width': 0,
#   'annotations': [{'bbox': [array([0.36077, 0.656517, 0.41038199999999997, 0.8860370000000001],
#            dtype=object)],
#     'bbox_mode': 0,
#     'category_id': 3}]},
#  {'file_name': 'images/e6e05b56799fefba.jpg',
#   'image_id': 'e6e05b56799fefba',
#   'height': 0,
#   'width': 0,
#   'annotations': [{'bbox': [array([0.059556, 0.956108, 0.0, 0.5071829999999999], dtype=object)],
#     'bbox_mode': 0,
#     'category_id': 3}]},
#  {'file_name': 'images/539e0871494dea5d.jpg',
#   'image_id': '539e0871494dea5d',
#   'height': 0,
#   'width': 0,
#   'annotations': [{'bbox': [array([0.20127799999999998, 0.815655, 0.0, 1.0], dtype=object)],
#     'bbox_mode': 0,
#     'category_id': 3}]},
#  {'file_name': 'images/b821cc12eede040e.jpg',
#   'image_id': 'b821cc12eede040e',
#   'height': 0,
#   'width': 0,
#   'annotations': [{'bbox': [array([0.520803, 0.940757, 0.603367, 0.988894], dtype=object)],
#     'bbox_mode': 0,
#     'category_id': 3}]},
#  {'file_name': 'images/837b3d11ff02f116.jpg',
#   'image_id': '837b3d11ff02f116',
#   'height': 0,
#   'width': 0,
#   'annotations': [{'bbox': [array([0.0, 0.669035, 0.37294099999999997, 1.0], dtype=object)],
#     'bbox_mode': 0,
#     'category_id': 0}]}]
